# %% [markdown]
# ## Demo

# %%
import pandas as pd
from core.retriever import Retriever

r = Retriever(
    csv_path="data/data.csv",
    model_name="Qwen/Qwen3-Embedding-0.6B",  retrieve_k=64,
    reranker_name="BAAI/bge-reranker-v2-m3", top_k=8,  # optional
    rebuild_index=False
)

r.load()

query = "hicup"
nodes = r.search(query)

pd.DataFrame(
    [{"id": n.metadata["id"], "text": n.text, "score": n.score} for n in nodes]
).head(3)
# Out:
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#                                      id  \
# 0  3d6ab356-e155-4ad5-9a89-219b1501c39c
# 1  7ec19a40-fe3a-4f1d-9167-99f26b76b8d3
# 2  4a8f6437-6f3c-4869-b59d-d75c83397980
#
#                                                 text     score
# 0  อาการสะอึกซ้ำซาก (Recurrent hiccups) คืออาการส... -1.267578
# 1  วัคซีนฮิบคือวัคซีนที่ป้องกันการติดเชื้อแบคทีเร... -2.349609
# 2  วัคซีนฮิบใช้ป้องกันโรคเยื่อหุ้มสมองอักเสบ ปอดบ... -3.441406
