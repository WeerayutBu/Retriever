# %%
import pandas as pd
import requests

url = "http://127.0.0.1:8000/retrieve"
params = {"q": "what causes hiccups?"}

r = requests.get(url, params=params)
pd.DataFrame(r.json()['results']).head(3)
# Out:
#                                      id  \
# 0  f72e9168-1e9b-4d6d-8796-f619bdb40c6f
# 1  3109acbe-659d-4b08-aad1-321603a2d448
# 2  fd134b0d-4dc1-4320-af8c-491885da3a06
#
#                                                 text     score
# 0  อาการสะอึกเรื้อรัง (Persistent hiccups) คืออาก...  3.039062
# 1  อาการวิงเวียนศีรษะอาจเกิดจากไมเกรนหรือการเปลี่...  1.500000
# 2  สาเหตุเบื้องต้นของสะอึกเฉียบพลัน ได้แก่ การขยา...  1.384766
