# %%
import pandas as pd
import requests

url = "http://127.0.0.1:8000/retrieve"
params = {"q": "what causes hiccups?"}

r = requests.get(url, params=params)
pd.DataFrame(r.json()['results'])
# Out:
#                                      id  \
# 0  article_672c869996a92aa406c1e0ea-004
# 1  article_67d116660d1de5e6544d3241-006
# 2  article_67be8b3105b0fc0dbf453617-002
# 3  article_672c869996a92aa406c1e0ea-000
# 4  article_67be8b3105b0fc0dbf4537c8-003
# 5  article_672c869196a92aa406c1e08b-004
# 6  article_67d116660d1de5e6544d3ad7-005
# 7  article_67be8b3105b0fc0dbf452d83-001
#
#                                                 text     score
# 0  อาการสะอึกเรื้อรัง (Persistent hiccups) คืออาก...  3.222656
# 1  อาการวิงเวียนศีรษะอาจเกิดจากไมเกรนหรือการเปลี่...  1.576172
# 2  สาเหตุเบื้องต้นของสะอึกเฉียบพลัน ได้แก่ การขยา...  1.395508
# 3  Singultus หรืออาการสะอึกเป็นการเกร็งตัวของกะบั...  0.439453
# 4  สาเหตุหลักของเวียนศีรษะจากหูชั้นในได้แก่ โรคเว...  0.420166
# 5  ภาวะทางการแพทย์ที่ทำให้เกิดแก๊สและผายลมมากเกิน...  0.062347
# 6  การเปลี่ยนแปลงอุณหภูมิในกระเพาะอาหารอย่างฉับพล... -0.068542
# 7  การไหลย้อนของกรดในกระเพาะอาหารและหลอดอาหาร (ga... -0.491211
